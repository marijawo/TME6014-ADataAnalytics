# %% [markdown]
# # Phase 5: Insights, Visualization & Final Report – Specification

# %%
# Import dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_file = "datasets/telco_churn_clean_stage_2.csv"

df = pd.read_csv(data_file)

# Ensure churn column is correctly encoded
if df['churn'].dtype == 'object':
    df['churn'] = df['churn'].map({'Yes': 1, 'No': 0})

# Separate features and target
X = df.drop(columns=['churn'])
y = df['churn']

df.head(3)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-vhveg  female              0     yes         no       1           no
# 1  5575-gnvde    male              0      no         no      34          yes
# 2  3668-qpybk    male              0      no         no       2          yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  no phone service             dsl             no  ...               no
# 1                no             dsl            yes  ...              yes
# 2                no             dsl            yes  ...               no
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          no          no              no  month-to-month              yes
# 1          no          no              no        one year               no
# 2          no          no              no  month-to-month              yes
#
#       PaymentMethod MonthlyCharges  TotalCharges  churn
# ...

# %% [markdown]
# ### 1. Visual 1: Churn Distribution Chart
#
# A simple but essential starting point showing how many customers churned vs. stayed.
#
# #### What it communicates
# - The degree of class imbalance.
# - The baseline difficulty of the prediction task.
# - Supports KPI alignment (e.g., targeting top 10% high-risk customers).

# %%
# X = X.drop(columns=['customerID'], errors='ignore')
#
# sns.countplot(x=y, palette="Blues")
# plt.title("Churn Distribution")
# plt.xlabel("Churn (0 = No, 1 = Yes)")
# plt.ylabel("Number of Customers")
# plt.show()

# %% [markdown]
# ### Feature Importance – Using BEST GRADIENT BOOSTING MODEL

# %%
from assignments.phase_4.phase_4_from_phase_3 import best_gb

feature_importances = pd.DataFrame({
    "Feature": X.columns,
    "Importance": best_gb.feature_importances_
}).sort_values("Importance", ascending=False)

feature_importances.head(15).plot(
    kind="barh", x="Feature", y="Importance", figsize=(8,6), color="steelblue"
)
plt.gca().invert_yaxis()
plt.title("Top 15 Important Features – Gradient Boosting (Using Clean Stage 2 Data)")
plt.xlabel("Importance Score")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from assignments.phase_4.phase_4_from_phase_3 import best_gb
#       3 feature_importances = pd.DataFrame({
#       4     "Feature": X.columns,
#       5     "Importance": best_gb.feature_importances_
#       6 }).sort_values("Importance", ascending=False)
#       8 feature_importances.head(15).plot(
#       9     kind="barh", x="Feature", y="Importance", figsize=(8,6), color="steelblue"
#      10 )
#
# ModuleNotFoundError: No module named 'assignments.phase_4.phase_4_from_phase_3'
